# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import requests
import math
from census import Census
from pprint import pprint

# Census API Key
from config import api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-05886cdaa77b> in <module>
#      10
#      11 # Census API Key
# ---> 12 from config import api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Pull and read data files for All RVA and for each selected Neighborhood
allRVA_data = pd.read_csv("Output/richmond.csv")
manchester_data = pd.read_csv("Output/manchester.csv")
oregon_hill_data = pd.read_csv("Output/oregon_hill.csv")
scotts_addition_data =pd.read_csv("Output/scotts_addition.csv")
jackson_ward_data = pd.read_csv("Output/jackson_ward.csv")
shockoe_bottom_data = pd.read_csv("Output/shockoe_bottom.csv")
church_hill_data = pd.read_csv("Output/church_hill.csv")
church_hill_north_data = pd.read_csv("Output/church_hill_north.csv")

# %%
# Show one
allRVA_data
# Out:
#     YEAR NEIGHBORHOOD_NAME  HOMICIDE  SEX_OFFENSE  ROBBERY  ASSAULT  BURGLARY  \
# 0   2000          Richmond        75          296     1091     5908      2841
# 1   2001          Richmond        67          291     1328     6341      2871
# 2   2002          Richmond        83          356     1316     5718      3039
# 3   2003          Richmond        88          273     1336     5699      3113
# 4   2004          Richmond        90          245     1304     5351      2716
# 5   2005          Richmond        83          238     1196     5239      2511
# 6   2006          Richmond        72          216      995     5447      2281
# 7   2007          Richmond        55          168      962     5334      1875
# 8   2008          Richmond        31          158      772     4980      1748
# 9   2009          Richmond        43          152      849     5082      1584
# 10  2010          Richmond        44          149      730     5068      1766
# ...

# %%
# Create a new DataFrame/csv comparing violent and non-violent crime
crime_type_df = pd.DataFrame()
neighborhoods = []
v_crime = []
nv_crime = []
other = []

# All RVA
neighborhoods.append('RICHMOND AVERAGE')
v_crime.append(((allRVA_data.iloc[0, 2]) + (allRVA_data.iloc[0, 3]) + (allRVA_data.iloc[0, 4]) + (allRVA_data.iloc[0, 5]))/149)
nv_crime.append(((allRVA_data.iloc[0, 6]) + (allRVA_data.iloc[0, 7]) + (allRVA_data.iloc[0, 8]) + (allRVA_data.iloc[0, 9]))/149)
other.append((allRVA_data.iloc[0, 10])/149)

neighborhoods.append('RICHMOND AVERAGE')
v_crime.append(((allRVA_data.iloc[20, 2]) + (allRVA_data.iloc[20, 3]) + (allRVA_data.iloc[20, 4]) + (allRVA_data.iloc[20, 5]))/149)
nv_crime.append(((allRVA_data.iloc[20, 6]) + (allRVA_data.iloc[20, 7]) + (allRVA_data.iloc[20, 8]) + (allRVA_data.iloc[20, 9]))/149)
other.append((allRVA_data.iloc[20, 10])/149)

# Manchester
neighborhoods.append(manchester_data.iloc[0, 1])
v_crime.append((manchester_data.iloc[0, 2]) + (manchester_data.iloc[0, 3]) + (manchester_data.iloc[0, 4]) + (manchester_data.iloc[0, 5]))
nv_crime.append((manchester_data.iloc[0, 6]) + (manchester_data.iloc[0, 7]) + (manchester_data.iloc[0, 8]) + (manchester_data.iloc[0, 9]))
other.append(manchester_data.iloc[0, 10])

neighborhoods.append(manchester_data.iloc[20, 1])
v_crime.append((manchester_data.iloc[20, 2]) + (manchester_data.iloc[20, 3]) + (manchester_data.iloc[20, 4]) + (manchester_data.iloc[20, 5]))
nv_crime.append((manchester_data.iloc[20, 6]) + (manchester_data.iloc[20, 7]) + (manchester_data.iloc[20, 8]) + (manchester_data.iloc[20, 9]))
other.append(manchester_data.iloc[20, 10])

# Oregon Hill
neighborhoods.append(oregon_hill_data.iloc[0, 1])
v_crime.append((oregon_hill_data.iloc[0, 2]) + (oregon_hill_data.iloc[0, 3]) + (oregon_hill_data.iloc[0, 4]) + (oregon_hill_data.iloc[0, 5]))
nv_crime.append((oregon_hill_data.iloc[0, 6]) + (oregon_hill_data.iloc[0, 7]) + (oregon_hill_data.iloc[0, 8]) + (oregon_hill_data.iloc[0, 9]))
other.append(oregon_hill_data.iloc[0, 10])

neighborhoods.append(oregon_hill_data.iloc[20, 1])
v_crime.append((oregon_hill_data.iloc[20, 2]) + (oregon_hill_data.iloc[20, 3]) + (oregon_hill_data.iloc[20, 4]) + (oregon_hill_data.iloc[20, 5]))
nv_crime.append((oregon_hill_data.iloc[20, 6]) + (oregon_hill_data.iloc[20, 7]) + (oregon_hill_data.iloc[20, 8]) + (oregon_hill_data.iloc[20, 9]))
other.append(oregon_hill_data.iloc[20, 10])

# Scotts Addition
neighborhoods.append(scotts_addition_data.iloc[0, 1])
v_crime.append((scotts_addition_data.iloc[0, 2]) + (scotts_addition_data.iloc[0, 3]) + (scotts_addition_data.iloc[0, 4]) + (scotts_addition_data.iloc[0, 5]))
nv_crime.append((scotts_addition_data.iloc[0, 6]) + (scotts_addition_data.iloc[0, 7]) + (scotts_addition_data.iloc[0, 8]) + (scotts_addition_data.iloc[0, 9]))
other.append(scotts_addition_data.iloc[0, 10])

neighborhoods.append(scotts_addition_data.iloc[20, 1])
v_crime.append((scotts_addition_data.iloc[20, 2]) + (scotts_addition_data.iloc[20, 3]) + (scotts_addition_data.iloc[20, 4]) + (scotts_addition_data.iloc[20, 5]))
nv_crime.append((scotts_addition_data.iloc[20, 6]) + (scotts_addition_data.iloc[20, 7]) + (scotts_addition_data.iloc[20, 8]) + (scotts_addition_data.iloc[20, 9]))
other.append(scotts_addition_data.iloc[20, 10])

# Jackson Ward
neighborhoods.append(jackson_ward_data.iloc[0, 1])
v_crime.append((jackson_ward_data.iloc[0, 2]) + (jackson_ward_data.iloc[0, 3]) + (jackson_ward_data.iloc[0, 4]) + (jackson_ward_data.iloc[0, 5]))
nv_crime.append((jackson_ward_data.iloc[0, 6]) + (jackson_ward_data.iloc[0, 7]) + (jackson_ward_data.iloc[0, 8]) + (jackson_ward_data.iloc[0, 9]))
other.append(jackson_ward_data.iloc[0, 10])

neighborhoods.append(jackson_ward_data.iloc[20, 1])
v_crime.append((jackson_ward_data.iloc[20, 2]) + (jackson_ward_data.iloc[20, 3]) + (jackson_ward_data.iloc[20, 4]) + (jackson_ward_data.iloc[20, 5]))
nv_crime.append((jackson_ward_data.iloc[20, 6]) + (jackson_ward_data.iloc[20, 7]) + (jackson_ward_data.iloc[20, 8]) + (jackson_ward_data.iloc[20, 9]))
other.append(jackson_ward_data.iloc[20, 10])

# Shockoe Bottom
neighborhoods.append(shockoe_bottom_data.iloc[0, 1])
v_crime.append((shockoe_bottom_data.iloc[0, 2]) + (shockoe_bottom_data.iloc[0, 3]) + (shockoe_bottom_data.iloc[0, 4]) + (shockoe_bottom_data.iloc[0, 5]))
nv_crime.append((shockoe_bottom_data.iloc[0, 6]) + (shockoe_bottom_data.iloc[0, 7]) + (shockoe_bottom_data.iloc[0, 8]) + (shockoe_bottom_data.iloc[0, 9]))
other.append(shockoe_bottom_data.iloc[0, 10])

neighborhoods.append(shockoe_bottom_data.iloc[20, 1])
v_crime.append((shockoe_bottom_data.iloc[20, 2]) + (shockoe_bottom_data.iloc[20, 3]) + (shockoe_bottom_data.iloc[20, 4]) + (shockoe_bottom_data.iloc[20, 5]))
nv_crime.append((shockoe_bottom_data.iloc[20, 6]) + (shockoe_bottom_data.iloc[20, 7]) + (shockoe_bottom_data.iloc[20, 8]) + (shockoe_bottom_data.iloc[20, 9]))
other.append(shockoe_bottom_data.iloc[20, 10])

# Church Hill
neighborhoods.append(church_hill_data.iloc[0, 1])
v_crime.append((church_hill_data.iloc[0, 2]) + (church_hill_data.iloc[0, 3]) + (church_hill_data.iloc[0, 4]) + (church_hill_data.iloc[0, 5]))
nv_crime.append((church_hill_data.iloc[0, 6]) + (church_hill_data.iloc[0, 7]) + (church_hill_data.iloc[0, 8]) + (church_hill_data.iloc[0, 9]))
other.append(church_hill_data.iloc[0, 10])

neighborhoods.append(church_hill_data.iloc[20, 1])
v_crime.append((church_hill_data.iloc[20, 2]) + (church_hill_data.iloc[20, 3]) + (church_hill_data.iloc[20, 4]) + (church_hill_data.iloc[20, 5]))
nv_crime.append((church_hill_data.iloc[20, 6]) + (church_hill_data.iloc[20, 7]) + (church_hill_data.iloc[20, 8]) + (church_hill_data.iloc[20, 9]))
other.append(church_hill_data.iloc[20, 10])

# Church Hill North
neighborhoods.append(church_hill_north_data.iloc[0, 1])
v_crime.append((church_hill_north_data.iloc[0, 2]) + (church_hill_north_data.iloc[0, 3]) + (church_hill_north_data.iloc[0, 4]) + (church_hill_north_data.iloc[0, 5]))
nv_crime.append((church_hill_north_data.iloc[0, 6]) + (church_hill_north_data.iloc[0, 7]) + (church_hill_north_data.iloc[0, 8]) + (church_hill_north_data.iloc[0, 9]))
other.append(church_hill_north_data.iloc[0, 10])

neighborhoods.append(church_hill_north_data.iloc[20, 1])
v_crime.append((church_hill_north_data.iloc[20, 2]) + (church_hill_north_data.iloc[20, 3]) + (church_hill_north_data.iloc[20, 4]) + (church_hill_north_data.iloc[20, 5]))
nv_crime.append((church_hill_north_data.iloc[20, 6]) + (church_hill_north_data.iloc[20, 7]) + (church_hill_north_data.iloc[20, 8]) + (church_hill_north_data.iloc[20, 9]))
other.append(church_hill_north_data.iloc[20, 10])

# Pass in all data into DataFrame
crime_type_df["YEAR"] = ["2000", "2020", "2000", "2020", "2000", "2020", "2000", "2020", "2000", "2020", "2000", "2020", "2000", "2020", "2000", "2020"]
crime_type_df["NEIGHBORHOOD_NAME"] = neighborhoods
crime_type_df["VIOLENT_CRIME"] = v_crime
crime_type_df["NON-VIOLENT_CRIME"] = nv_crime
crime_type_df["OTHER"] = other

# Show DataFrame
crime_type_df
# Out:
#     YEAR  NEIGHBORHOOD_NAME  VIOLENT_CRIME  NON-VIOLENT_CRIME       OTHER
# 0   2000   RICHMOND AVERAGE      49.463087         125.402685  144.818792
# 1   2020   RICHMOND AVERAGE      27.416107          60.798658  110.013423
# 2   2000         MANCHESTER      49.000000         113.000000  130.000000
# 3   2020         MANCHESTER      19.000000         105.000000  144.000000
# 4   2000        OREGON HILL      23.000000          48.000000   62.000000
# 5   2020        OREGON HILL       7.000000          35.000000   62.000000
# 6   2000   SCOTT'S ADDITION      34.000000         247.000000  147.000000
# 7   2020   SCOTT'S ADDITION      20.000000          96.000000  134.000000
# 8   2000       JACKSON WARD     101.000000         396.000000  344.000000
# 9   2020       JACKSON WARD      43.000000         209.000000  267.000000
# 10  2000     SHOCKOE BOTTOM      59.000000         249.000000  310.000000
# 11  2020     SHOCKOE BOTTOM      70.000000         223.000000  336.000000
# ...

# %%
# Save to csv
crime_type_df.to_csv("Output/crime_type_data2.csv", encoding="utf-8", index=True)
